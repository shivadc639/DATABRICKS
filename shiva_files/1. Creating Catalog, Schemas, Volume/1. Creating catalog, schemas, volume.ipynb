# %%
# %fs ls 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/landing/operational'

# %% [markdown]
# ## 1. Create Calatog

# %%
# %sql
create catalog if not exists gizmobox
managed location 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/'

# %% [markdown]
# ## 2. Create below schemas:
#
# - Landing
# - Bronze
# - Silver
# - Gold

# %%
# %sql
select current_catalog()

# %%
# %sql

create schema landing
managed location 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/landing'

# %%
# %sql
create schema if not exists bronze
managed location 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/bronze';
create schema if not exists silver
managed location 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/silver';
create schema if not exists gold
managed location 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/gold';

# %%
# %sql
show schemas

# %% [markdown]
# ## 3. create volume under landing schema

# %%
# %sql
use catalog gizmobox;
use schema landing;
create external volume if not exists operations_volume
location 'abfss://dbdeblob@dbdeassociatesa.dfs.core.windows.net/landing/operational/';
