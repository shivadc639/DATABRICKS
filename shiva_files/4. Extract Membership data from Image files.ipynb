-- %% [markdown]
-- ## Extract data from Memebrships Imange file
-- ### 1. Query Memebrships file from `binaryFile` format.
-- ### 2. Create Memebrships view in bronze schema.

-- %% [markdown]
-- ### 1. Query Memebrships file from `binaryFile` format.

-- %%
%fs ls '/Volumes/gizmobox/landing/operations_volume/memberships/'

-- %%
SELECT * FROM binaryFile.`/Volumes/gizmobox/landing/operations_volume/memberships/*`;

-- %% [markdown]
-- ### 2. Create Memebrships view in bronze schema.

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_memberships
AS
SELECT * FROM binaryFile.`/Volumes/gizmobox/landing/operations_volume/memberships/*`;

-- %%
SELECT * FROM gizmobox.bronze.v_memberships;
